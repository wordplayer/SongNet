# %%
import tensorflow as tf
import numpy as np
from numpy import save, asarray
import matplotlib.pyplot as plt
from tensorflow.keras import backend as K
from tensorflow import keras
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import pickle
from IPython.display import Image
import os

import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.27)})
import json
import sys
from batchup import data_source
from collections import Counter

from sklearn.cluster import KMeans, SpectralClustering

from sklearn.metrics import silhouette_samples, silhouette_score
import matplotlib.cm as cm

from sklearn import metrics 
from scipy.spatial.distance import cdist

from sklearn.manifold import TSNE

from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA
import pandas as pd

from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
tf.keras.backend.clear_session()

# %%
models_path = '/datasets/home/21/321/ee228sp20ta1/G51/models/'
val_path = '/datasets/home/21/321/ee228sp20ta1/G51/val_set.npy'
val_ids_path = '/datasets/home/21/321/ee228sp20ta1/G51/val_ids.txt'

# %%
f=open(val_ids_path, "r")
val_spec_ids = f.read()
val_spec_labels = val_spec_ids.split('\n')

# %%
X_valid = np.load(val_path)
X_valid = X_valid.reshape((2763*96,216))

unscaled_val_set = X_valid.reshape(2763,96,216,1)

print(X_valid.shape)

scaler = MinMaxScaler().fit(X_valid) 
scaled_valid = scaler.transform(X_valid)


s_valid_reshaped = scaled_valid.reshape(2763,96,216,1)
val_set = s_valid_reshaped
# Out:
# (265248, 216)

# %%
def ModelC():
    
    #### Encoder ####
    model = models.Sequential()
    model.add(keras.Input(shape=(96,216,1)))
    model.add(layers.Conv2D(48, (3, 3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(24, (3, 3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(12, (3, 3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(5, (3, 3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((3, 3)))
    
    #### Decoder ####
    model.add(layers.Conv2D(5, (3, 3), activation='relu', padding='same'))
    model.add(layers.UpSampling2D(size=(3,3)))
    model.add(layers.Conv2D(12, (3, 3), activation='relu', padding='same'))
    model.add(layers.UpSampling2D(size=(2,2)))
    model.add(layers.Conv2D(24, (3, 3), activation='relu', padding='same'))
    model.add(layers.UpSampling2D(size=(2,2)))
    model.add(layers.Conv2D(48, (3, 3), activation='relu', padding='same'))
    model.add(layers.UpSampling2D(size=(2,2)))
    model.add(layers.Conv2D(1,(3, 3), padding='same'))
    
    return model

# %%
AE_C = ModelC()

cwd = os.getcwd()
AE_C.load_weights(cwd+'/ExpTestModels228/ModelC/modelC')
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
ds = data_source.ArrayDataSource([val_set])

latent_vecs = []

get_hl = K.function([AE_C.layers[0].input], [AE_C.layers[8].output])

for batch in ds.batch_iterator(batch_size=64, shuffle=False):
    AE_h1 = get_hl([batch])[0]
    latent_vecs.append(AE_h1)
    
latent_vecs = asarray(latent_vecs)
latent_vecs = np.concatenate(latent_vecs)

# %%
latent_vectors = np.ndarray(shape=(2763,12,15))

for idx, spec in enumerate(val_set):
    latent_vec = latent_vecs[idx].reshape(12,15)
    latent_vectors[idx] = latent_vec

reshaped_latent_vectors = latent_vectors.reshape(2763,180)
X = reshaped_latent_vectors

# %%
stdout_obj = sys.stdout             # store original stdout 

sys.stdout = open("{}_silhouette.txt".format('ModelC'), "w")

range_n_clusters = [2,3,4,5,6,8,10]

for n_clusters in range_n_clusters:
    # Create a subplot with 1 row and 2 columns
    fig, ax1 = plt.subplots(1, 1)
    fig.set_size_inches(18, 7)

    # The 1st subplot is the silhouette plot
    # The silhouette coefficient can range from -1, 1 but in this example all
    # lie within [-0.1, 1]
    ax1.set_xlim([-0.1, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, len(X) + (n_clusters + 1) * 10])

    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    clusterer = KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(X)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(X, cluster_labels)
    print("For n_clusters =", n_clusters,
          "The average silhouette_score is :", silhouette_avg)

    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(X, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to
        # cluster i, and sort them
        ith_cluster_silhouette_values = \
            sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    plt.suptitle(("Silhouette analysis for KMeans clustering on sample data "
                  "with n_clusters = %d" % n_clusters),
                 fontsize=14, fontweight='bold')
    
plt.show()

sys.stdout.close()
sys.stdout = stdout_obj

# %%
distortions = [] 
inertias = [] 
mapping1 = {} 
mapping2 = {}

range_n_clusters = [2,3,4,5,6,8,10]

for k in range_n_clusters:
    
    #Building and fitting the model 
    kmeanModel = KMeans(n_clusters=k).fit(X) 
    kmeanModel.fit(X)     
      
    distortions.append(sum(np.min(cdist(X, kmeanModel.cluster_centers_, 
                      'euclidean'),axis=1)) / X.shape[0]) 
    inertias.append(kmeanModel.inertia_) 
  
    mapping1[k] = sum(np.min(cdist(X, kmeanModel.cluster_centers_, 
                 'euclidean'),axis=1)) / X.shape[0] 
    mapping2[k] = kmeanModel.inertia_

# %%
plt.plot(range_n_clusters, distortions, 'bx-') 
plt.xlabel('Values of K') 
plt.ylabel('Distortion') 
plt.title('The Elbow Method using Distortion') 
plt.savefig('{}_elbow_distortion.png'.format('ModelC'), dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.plot(range_n_clusters, inertias, 'bx-') 
plt.xlabel('Values of K') 
plt.ylabel('Inertia') 
plt.title('The Elbow Method using Inertia') 
plt.savefig('{}_elbow_inertia.png'.format('ModelC'), dpi=300, bbox_inches='tight')
plt.show()

# %%
nclusters = 3
kmeans = KMeans(n_clusters=nclusters, init='k-means++', verbose =1).fit(reshaped_latent_vectors)
# Out:
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 650.790081962431
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 618.9973305468349
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 607.9356878927608
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 603.3041211053519
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 600.7015801042955
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 599.0413240075397
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 597.9628581394136
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 597.1964758421584
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 596.5340053036698
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 596.1064959626847
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 595.9269204070521
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 595.8249554582973
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 595.7332154401691
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 595.6620892461541
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 595.626279365549
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 595.6021648778509
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 595.5892642025548
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 595.5871490456567
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 595.5849076774665
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 595.5824269077727
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 595.5798510750844
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 595.5781434956847
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 595.5778604220493
# start iteration
# done sorting
# end inner loop
# Iteration 23, inertia 595.5762250433864
# start iteration
# done sorting
# end inner loop
# Iteration 24, inertia 595.5762250433864
# center shift 0.000000e+00 within tolerance 1.708603e-07
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 673.7301018037014
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 641.2997290784743
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 629.4340340979167
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 614.0377770370077
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 602.7974228282258
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 597.7424012637717
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 596.3767042978894
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 595.9690033275473
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 595.782395133406
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 595.6735580691918
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 595.6480392128867
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 595.6290613747167
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 595.6180608204158
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 595.6086253385896
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 595.5909246744689
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 595.5808124431437
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 595.573635357547
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 595.5721495471362
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 595.5721495471362
# center shift 0.000000e+00 within tolerance 1.708603e-07
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 639.5113136223246
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 606.5420741008345
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 600.818351276107
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 598.8363170702303
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 597.5878231454051
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 596.7964814440289
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 596.353337689466
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 596.0723284235638
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 595.8557300801687
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 595.744022770958
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 595.6719515465288
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 595.646447783112
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 595.6290613747167
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 595.6180608204158
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 595.6086253385896
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 595.5909246744689
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 595.5808124431437
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 595.573635357547
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 595.5721495471362
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 595.5721495471362
# center shift 0.000000e+00 within tolerance 1.708603e-07
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 650.8520499696671
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 626.2750347370127
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 619.7340674390724
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 613.4095080603089
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 606.6107396321007
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 602.1258298607953
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 599.7920353306091
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 598.3943426296975
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 597.516239512545
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 596.7723802893602
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 596.2423041626489
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 595.9737596990419
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 595.8566713160526
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 595.7657401955404
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 595.6777170300999
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 595.6280709524809
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 595.6021648778509
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 595.5892642025548
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 595.5871490456567
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 595.5849076774665
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 595.5824269077727
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 595.5798510750844
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 595.5781434956847
# start iteration
# done sorting
# end inner loop
# Iteration 23, inertia 595.5778604220493
# start iteration
# done sorting
# end inner loop
# Iteration 24, inertia 595.5762250433864
# start iteration
# done sorting
# end inner loop
# Iteration 25, inertia 595.5762250433864
# center shift 0.000000e+00 within tolerance 1.708603e-07
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 606.7846108291194
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 597.0981763685222
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 596.1738691322394
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 595.9244549005678
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 595.767447533262
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 595.6719515465288
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 595.646447783112
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 595.6290613747167
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 595.6180608204158
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 595.6086253385896
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 595.5909246744689
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 595.5808124431437
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 595.573635357547
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 595.5721495471362
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 595.5721495471362
# center shift 0.000000e+00 within tolerance 1.708603e-07
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 662.0890318733309
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 603.8134052211309
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 597.7102245499998
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 596.4148844607597
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 595.989921251169
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 595.8550842539175
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 595.7625756865369
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 595.6777170300999
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 595.6280709524809
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 595.6021648778509
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 595.5892642025548
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 595.5871490456567
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 595.5849076774665
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 595.5824269077727
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 595.5798510750844
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 595.5781434956847
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 595.5778604220493
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 595.5762250433864
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 595.5762250433864
# center shift 0.000000e+00 within tolerance 1.708603e-07
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 632.6980393395304
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 602.4054387933126
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 599.9708290450264
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 598.5487067296957
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 597.5993960523508
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 596.8363875860358
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 596.2755923634163
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 595.9793295517223
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 595.8649669238112
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 595.7684213562391
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 595.681011371605
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 595.6280709524809
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 595.6021648778509
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 595.5892642025548
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 595.5871490456567
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 595.5849076774665
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 595.5824269077727
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 595.5798510750844
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 595.5781434956847
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 595.5778604220493
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 595.5762250433864
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 595.5762250433864
# center shift 0.000000e+00 within tolerance 1.708603e-07
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 673.9498408168624
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 617.4432752632246
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 606.2476314351517
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 601.7003658771856
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 599.2436532213783
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 597.7475565142311
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 596.8486589337289
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 596.2930780769499
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 595.9854440743005
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 595.8676254005692
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 595.7723016783257
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 595.6836823543647
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 595.6280709524809
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 595.6021648778509
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 595.5892642025548
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 595.5871490456567
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 595.5849076774665
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 595.5824269077727
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 595.5798510750844
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 595.5781434956847
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 595.5778604220493
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 595.5762250433864
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 595.5762250433864
# center shift 0.000000e+00 within tolerance 1.708603e-07
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 619.7932068615994
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 596.8425409110632
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 595.6849736825081
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 595.5773041610724
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 595.5722296335446
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 595.571723099348
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 595.5709782676162
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 595.5709782676162
# center shift 0.000000e+00 within tolerance 1.708603e-07
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 631.1389476023237
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 613.1034108167356
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 603.6000486180786
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 597.4597533001547
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 595.823987510384
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 595.6049576080442
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 595.5791292079138
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 595.5726501548797
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 595.571890148217
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 595.571890148217
# center shift 0.000000e+00 within tolerance 1.708603e-07

# %%
cluster_labels = kmeans.labels_

# %%
community_json = 'val_communities_3.json'

with open(community_json) as json_file:
    community_labels = json.load(json_file)

# %%
kmeans_labels = dict()
for idx, label in zip(val_spec_labels, cluster_labels):
    kmeans_labels[idx] = label

sorted_kmeans_labels = dict(sorted(kmeans_labels.items()))

sorted_community_labels = dict(sorted(community_labels.items()))

#This should be True
sorted_community_labels.keys() == sorted_kmeans_labels.keys()
# Out:
# True

# %%
community_labels = list(sorted_community_labels.values())
cluster_labels = list(sorted_kmeans_labels.values())

# %%
Counter(community_labels)
# Out:
# Counter({0: 2706, 1: 28, 3: 20, 2: 9})

# %%
Counter(cluster_labels)
# Out:
# Counter({1: 698, 2: 1173, 0: 892})

# %%
labels = kmeans.labels_
community = list(sorted_community_labels.values())
kmeanclusters = list(sorted_kmeans_labels.values())

mat = confusion_matrix(community, kmeanclusters)
fig, ax = plt.subplots(figsize=(12,12))  

sns.heatmap(mat.T, square=False, annot=True, fmt='d', cbar=False, cmap="YlGnBu", ax=ax)
plt.xlabel('igraph communities')
plt.ylabel('kmean cluster');
plt.title('Confusion Matrix for Model C')
plt.savefig('{}_confusion_matrix.png'.format('ModelC'), dpi=300, bbox_inches='tight')

# %%
X_embedded = TSNE(n_components=2).fit_transform(reshaped_latent_vectors)

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.scatterplot(X_embedded[:,0], X_embedded[:,1], hue=cluster_labels, legend='full')
plt.title('TSNE with cluster labels')
plt.savefig('{}_tnse_clusters.png'.format('ModelC'), dpi=300, bbox_inches='tight')

# %%
sns.scatterplot(X_embedded[:,0], X_embedded[:,1], hue=community_labels, legend='full')
plt.title('TSNE with Community labels')
plt.savefig('{}_tsne_community.png'.format('ModelC'), dpi=300, bbox_inches='tight')

# %%
df = pd.DataFrame()
pca = PCA(n_components=3)
pca_result = pca.fit_transform(X)
df['pca-one'] = pca_result[:,0]
df['pca-two'] = pca_result[:,1] 
df['pca-three'] = pca_result[:,2]
print('Explained variation per principal component: {}'.format(pca.explained_variance_ratio_))
# Out:
# Explained variation per principal component: [0.35882766 0.06678224 0.03790037]

# %%
ax = plt.figure(figsize=(16,10)).gca(projection='3d')
ax.scatter(
    xs=df.loc[:,:]["pca-one"], 
    ys=df.loc[:,:]["pca-two"], 
    zs=df.loc[:,:]["pca-three"], 
    c=cluster_labels, 
    cmap='tab10'
)
ax.set_xlabel('pca-one')
ax.set_ylabel('pca-two')
ax.set_zlabel('pca-three')
plt.title('PCA with Cluster Labels')
plt.savefig('{}_pca_clusters.png'.format("ModelC"), dpi=300, bbox_inches='tight')

plt.show()

# %%
ax = plt.figure(figsize=(16,10)).gca(projection='3d')
ax.scatter(
    xs=df.loc[:,:]["pca-one"], 
    ys=df.loc[:,:]["pca-two"], 
    zs=df.loc[:,:]["pca-three"], 
    c=community_labels, 
    cmap='tab10'
)
ax.set_xlabel('pca-one')
ax.set_ylabel('pca-two')
ax.set_zlabel('pca-three')
plt.title('PCA with Community Labels')
plt.savefig('{}_pca_community.png'.format("ModelC"), dpi=300, bbox_inches='tight')
plt.show()
