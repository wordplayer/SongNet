# %%
import tensorflow as tf
import numpy as np
from numpy import save, asarray
import matplotlib.pyplot as plt
from tensorflow.keras import backend as K
from tensorflow import keras
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import pickle
from IPython.display import Image
import os

import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.27)})
import json
import sys
from batchup import data_source
from collections import Counter

from sklearn.cluster import KMeans, SpectralClustering

from sklearn.metrics import silhouette_samples, silhouette_score
import matplotlib.cm as cm

from sklearn import metrics 
from scipy.spatial.distance import cdist

from sklearn.manifold import TSNE

from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA
import pandas as pd

from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
tf.keras.backend.clear_session()

# %%
models_path = '/datasets/home/21/321/ee228sp20ta1/G51/models/'
val_path = '/datasets/home/21/321/ee228sp20ta1/G51/val_set.npy'
val_ids_path = '/datasets/home/21/321/ee228sp20ta1/G51/val_ids.txt'

# %%
f=open(val_ids_path, "r")
val_spec_ids = f.read()
val_spec_labels = val_spec_ids.split('\n')

# %%
X_valid = np.load(val_path)
X_valid = X_valid.reshape((2763*96,216))

unscaled_val_set = X_valid.reshape(2763,96,216,1)

print(X_valid.shape)

scaler = MinMaxScaler().fit(X_valid) 
scaled_valid = scaler.transform(X_valid)


s_valid_reshaped = scaled_valid.reshape(2763,96,216,1)
val_set = s_valid_reshaped
# Out:
# (265248, 216)

# %%
def ModelA():
    
    #### Encoder ####
    model = models.Sequential()
    model.add(keras.Input(shape=(96,216,1)))
    model.add(layers.Conv2D(48, (3, 3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(24, (3, 3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(12, (3, 3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D((2, 2)))
    
    #### Decoder ####
    model.add(layers.Conv2D(12, (3, 3), activation='relu', padding='same'))
    model.add(layers.UpSampling2D(size=(2,2)))
    model.add(layers.Conv2D(24, (3, 3), activation='relu', padding='same'))
    model.add(layers.UpSampling2D(size=(2,2)))
    model.add(layers.Conv2D(48, (3, 3), activation='relu', padding='same'))
    model.add(layers.UpSampling2D(size=(2,2)))
    model.add(layers.Conv2D(1,(3, 3), padding='same'))
    
    return model

# %%
AE_A = ModelA()

cwd = os.getcwd()
AE_A.load_weights(cwd+'/ExpTestModels228/ModelA2/modelA2')
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
ds = data_source.ArrayDataSource([val_set])

latent_vecs = []

get_hl = K.function([AE_A.layers[0].input], [AE_A.layers[6].output])

for batch in ds.batch_iterator(batch_size=64, shuffle=False):
    AE_h1 = get_hl([batch])[0]
    latent_vecs.append(AE_h1)
    
latent_vecs = asarray(latent_vecs)
latent_vecs = np.concatenate(latent_vecs)

# %%
latent_vectors = np.ndarray(shape=(2763,48,81))

for idx, spec in enumerate(val_set):
    latent_vec = latent_vecs[idx].reshape(48,81)
    latent_vectors[idx] = latent_vec

reshaped_latent_vectors = latent_vectors.reshape(2763,3888)
X = reshaped_latent_vectors

# %%
stdout_obj = sys.stdout             # store original stdout 

sys.stdout = open("{}_silhouette.txt".format('ModelA'), "w")

range_n_clusters = [2,3,4,5,6,8,10]

for n_clusters in range_n_clusters:
    # Create a subplot with 1 row and 2 columns
    fig, ax1 = plt.subplots(1, 1)
    fig.set_size_inches(18, 7)

    # The 1st subplot is the silhouette plot
    # The silhouette coefficient can range from -1, 1 but in this example all
    # lie within [-0.1, 1]
    ax1.set_xlim([-0.1, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, len(X) + (n_clusters + 1) * 10])

    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    clusterer = KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(X)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(X, cluster_labels)
    print("For n_clusters =", n_clusters,
          "The average silhouette_score is :", silhouette_avg)

    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(X, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to
        # cluster i, and sort them
        ith_cluster_silhouette_values = \
            sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    plt.suptitle(("Silhouette analysis for KMeans clustering on sample data "
                  "with n_clusters = %d" % n_clusters),
                 fontsize=14, fontweight='bold')
    
plt.show()

sys.stdout.close()
sys.stdout = stdout_obj

# %%
distortions = [] 
inertias = [] 
mapping1 = {} 
mapping2 = {}

range_n_clusters = [2,3,4,5,6,8,10]

for k in range_n_clusters:
    
    #Building and fitting the model 
    kmeanModel = KMeans(n_clusters=k).fit(X) 
    kmeanModel.fit(X)     
      
    distortions.append(sum(np.min(cdist(X, kmeanModel.cluster_centers_, 
                      'euclidean'),axis=1)) / X.shape[0]) 
    inertias.append(kmeanModel.inertia_) 
  
    mapping1[k] = sum(np.min(cdist(X, kmeanModel.cluster_centers_, 
                 'euclidean'),axis=1)) / X.shape[0] 
    mapping2[k] = kmeanModel.inertia_

# %%
plt.plot(range_n_clusters, distortions, 'bx-') 
plt.xlabel('Values of K') 
plt.ylabel('Distortion') 
plt.title('The Elbow Method using Distortion') 
plt.savefig('{}_elbow_distortion.png'.format('ModelA'), dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.plot(range_n_clusters, inertias, 'bx-') 
plt.xlabel('Values of K') 
plt.ylabel('Inertia') 
plt.title('The Elbow Method using Inertia') 
plt.savefig('{}_elbow_inertia.png'.format('ModelA'), dpi=300, bbox_inches='tight')
plt.show()

# %%
nclusters = 4
kmeans = KMeans(n_clusters=nclusters, init='k-means++', verbose =1).fit(reshaped_latent_vectors)
# Out:
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 29617.04997636815
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 28247.523960494953
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 28187.70966373505
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 28171.955914784456
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 28168.881570715548
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 28167.28247972812
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 28166.186649817726
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 28165.455270780563
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 28164.899392188483
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 28164.131182653156
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 28163.58724969132
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 28163.086969563195
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 28162.395909142087
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 28161.674276724
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 28161.437743902196
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 28161.39072586662
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 28161.294388162878
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 28161.146847753673
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 28161.117833706387
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 28161.086964476905
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 28161.06023222471
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 28161.06023222471
# center shift 0.000000e+00 within tolerance 3.062254e-07
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 30961.064017914916
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 29410.6405920498
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 28817.853442331787
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 28574.664927507947
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 28416.635670572487
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 28299.429893256543
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 28241.62960322772
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 28213.520513813666
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 28200.820019138428
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 28191.25996492512
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 28181.831908964174
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 28173.063387536105
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 28166.142665881456
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 28162.6626615315
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 28160.71845362942
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 28159.393732195233
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 28157.92247316158
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 28156.785686040963
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 28155.96983866994
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 28155.607137429062
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 28155.22692359732
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 28154.97560840809
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 28154.80264464878
# start iteration
# done sorting
# end inner loop
# Iteration 23, inertia 28154.384801207954
# start iteration
# done sorting
# end inner loop
# Iteration 24, inertia 28154.218722659047
# start iteration
# done sorting
# end inner loop
# Iteration 25, inertia 28153.975289060156
# start iteration
# done sorting
# end inner loop
# Iteration 26, inertia 28153.883000749134
# start iteration
# done sorting
# end inner loop
# Iteration 27, inertia 28153.883000749134
# center shift 0.000000e+00 within tolerance 3.062254e-07
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 29344.566486126867
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 28694.69524620066
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 28531.07418974501
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 28440.024794874764
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 28388.573396599775
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 28351.445813880367
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 28318.005569749388
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 28288.499576284838
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 28249.754726809722
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 28217.51651938784
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 28193.07708975519
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 28178.728979383966
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 28170.628528739126
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 28164.204867429322
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 28160.087421092176
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 28157.948124623173
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 28156.84592095818
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 28156.23708770856
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 28155.865857335568
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 28155.773003544306
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 28155.549743036314
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 28155.48807036856
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 28155.319116180326
# start iteration
# done sorting
# end inner loop
# Iteration 23, inertia 28155.23585364123
# start iteration
# done sorting
# end inner loop
# Iteration 24, inertia 28155.153555767163
# start iteration
# done sorting
# end inner loop
# Iteration 25, inertia 28155.153555767163
# center shift 0.000000e+00 within tolerance 3.062254e-07
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 29797.706947360777
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 28770.639374786537
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 28455.769282112615
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 28345.70422880016
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 28308.801694233993
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 28289.784270166576
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 28274.996130075127
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 28266.097304148367
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 28260.926893044023
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 28256.93934737496
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 28254.90816917205
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 28253.14793170016
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 28251.504972701176
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 28250.43174026943
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 28249.770446944705
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 28249.191224938466
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 28248.31615683593
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 28247.8711652096
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 28247.791783773748
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 28247.667168837947
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 28247.572441185283
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 28247.43343340726
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 28247.25884766368
# start iteration
# done sorting
# end inner loop
# Iteration 23, inertia 28246.93512326606
# start iteration
# done sorting
# end inner loop
# Iteration 24, inertia 28246.304954277228
# start iteration
# done sorting
# end inner loop
# Iteration 25, inertia 28245.629253632404
# start iteration
# done sorting
# end inner loop
# Iteration 26, inertia 28244.724804764588
# start iteration
# done sorting
# end inner loop
# Iteration 27, inertia 28243.555893801808
# start iteration
# done sorting
# end inner loop
# Iteration 28, inertia 28241.999822800317
# start iteration
# done sorting
# end inner loop
# Iteration 29, inertia 28240.507109011673
# start iteration
# done sorting
# end inner loop
# Iteration 30, inertia 28238.367700200193
# start iteration
# done sorting
# end inner loop
# Iteration 31, inertia 28234.995306034383
# start iteration
# done sorting
# end inner loop
# Iteration 32, inertia 28230.405178093682
# start iteration
# done sorting
# end inner loop
# Iteration 33, inertia 28224.579360446594
# start iteration
# done sorting
# end inner loop
# Iteration 34, inertia 28219.42238544248
# start iteration
# done sorting
# end inner loop
# Iteration 35, inertia 28214.50687441354
# start iteration
# done sorting
# end inner loop
# Iteration 36, inertia 28209.225414208042
# start iteration
# done sorting
# end inner loop
# Iteration 37, inertia 28203.617025346462
# start iteration
# done sorting
# end inner loop
# Iteration 38, inertia 28197.268881769687
# start iteration
# done sorting
# end inner loop
# Iteration 39, inertia 28192.23693338397
# start iteration
# done sorting
# end inner loop
# Iteration 40, inertia 28188.93144038563
# start iteration
# done sorting
# end inner loop
# Iteration 41, inertia 28186.08462034717
# start iteration
# done sorting
# end inner loop
# Iteration 42, inertia 28182.513948037893
# start iteration
# done sorting
# end inner loop
# Iteration 43, inertia 28179.212197629306
# start iteration
# done sorting
# end inner loop
# Iteration 44, inertia 28178.13664035898
# start iteration
# done sorting
# end inner loop
# Iteration 45, inertia 28176.85181108271
# start iteration
# done sorting
# end inner loop
# Iteration 46, inertia 28174.910339827908
# start iteration
# done sorting
# end inner loop
# Iteration 47, inertia 28172.549981869186
# start iteration
# done sorting
# end inner loop
# Iteration 48, inertia 28170.746791058704
# start iteration
# done sorting
# end inner loop
# Iteration 49, inertia 28168.59168263171
# start iteration
# done sorting
# end inner loop
# Iteration 50, inertia 28167.44804229096
# start iteration
# done sorting
# end inner loop
# Iteration 51, inertia 28167.171024500534
# start iteration
# done sorting
# end inner loop
# Iteration 52, inertia 28166.696430681044
# start iteration
# done sorting
# end inner loop
# Iteration 53, inertia 28166.212787632074
# start iteration
# done sorting
# end inner loop
# Iteration 54, inertia 28165.986633252647
# start iteration
# done sorting
# end inner loop
# Iteration 55, inertia 28165.70235279073
# start iteration
# done sorting
# end inner loop
# Iteration 56, inertia 28165.58450546868
# start iteration
# done sorting
# end inner loop
# Iteration 57, inertia 28165.433687171757
# start iteration
# done sorting
# end inner loop
# Iteration 58, inertia 28165.316259801497
# start iteration
# done sorting
# end inner loop
# Iteration 59, inertia 28165.26461487084
# start iteration
# done sorting
# end inner loop
# Iteration 60, inertia 28165.26461487084
# center shift 0.000000e+00 within tolerance 3.062254e-07
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 30052.241731398637
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 29013.87944299998
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 28653.867760692283
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 28560.09153550636
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 28526.033843309302
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 28517.241656133185
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 28513.474598672557
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 28512.165521419724
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 28511.671867670346
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 28511.502425977185
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 28511.477042417326
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 28511.477042417326
# center shift 0.000000e+00 within tolerance 3.062254e-07
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 29012.466394006424
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 28585.597690496845
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 28455.996026325825
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 28382.69543754128
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 28344.016153169014
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 28316.167451801364
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 28296.586386421393
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 28281.186182664573
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 28271.337593091033
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 28264.99304984804
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 28260.714152389966
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 28257.58856803484
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 28254.86993008035
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 28252.84698656313
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 28250.86754183609
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 28249.047576341414
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 28247.404947703297
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 28244.479035561504
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 28241.809426829364
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 28239.597138815876
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 28237.782228034637
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 28235.573554324088
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 28232.428164449593
# start iteration
# done sorting
# end inner loop
# Iteration 23, inertia 28229.459456350145
# start iteration
# done sorting
# end inner loop
# Iteration 24, inertia 28226.432198757306
# start iteration
# done sorting
# end inner loop
# Iteration 25, inertia 28223.496307676374
# start iteration
# done sorting
# end inner loop
# Iteration 26, inertia 28221.4524733534
# start iteration
# done sorting
# end inner loop
# Iteration 27, inertia 28219.182521056493
# start iteration
# done sorting
# end inner loop
# Iteration 28, inertia 28216.228775363936
# start iteration
# done sorting
# end inner loop
# Iteration 29, inertia 28213.932193787852
# start iteration
# done sorting
# end inner loop
# Iteration 30, inertia 28212.20806586193
# start iteration
# done sorting
# end inner loop
# Iteration 31, inertia 28209.354841465378
# start iteration
# done sorting
# end inner loop
# Iteration 32, inertia 28206.695820484543
# start iteration
# done sorting
# end inner loop
# Iteration 33, inertia 28203.403028291807
# start iteration
# done sorting
# end inner loop
# Iteration 34, inertia 28201.100552701573
# start iteration
# done sorting
# end inner loop
# Iteration 35, inertia 28199.08202342691
# start iteration
# done sorting
# end inner loop
# Iteration 36, inertia 28197.04012329253
# start iteration
# done sorting
# end inner loop
# Iteration 37, inertia 28195.350853949833
# start iteration
# done sorting
# end inner loop
# Iteration 38, inertia 28193.40628676577
# start iteration
# done sorting
# end inner loop
# Iteration 39, inertia 28191.55387864391
# start iteration
# done sorting
# end inner loop
# Iteration 40, inertia 28189.8502763802
# start iteration
# done sorting
# end inner loop
# Iteration 41, inertia 28188.30251311601
# start iteration
# done sorting
# end inner loop
# Iteration 42, inertia 28186.2151615659
# start iteration
# done sorting
# end inner loop
# Iteration 43, inertia 28184.672606857646
# start iteration
# done sorting
# end inner loop
# Iteration 44, inertia 28182.681067368358
# start iteration
# done sorting
# end inner loop
# Iteration 45, inertia 28180.39228190171
# start iteration
# done sorting
# end inner loop
# Iteration 46, inertia 28178.092679813497
# start iteration
# done sorting
# end inner loop
# Iteration 47, inertia 28175.2892183608
# start iteration
# done sorting
# end inner loop
# Iteration 48, inertia 28172.31932194433
# start iteration
# done sorting
# end inner loop
# Iteration 49, inertia 28169.78434963032
# start iteration
# done sorting
# end inner loop
# Iteration 50, inertia 28167.34810261893
# start iteration
# done sorting
# end inner loop
# Iteration 51, inertia 28166.32653419152
# start iteration
# done sorting
# end inner loop
# Iteration 52, inertia 28165.673160814626
# start iteration
# done sorting
# end inner loop
# Iteration 53, inertia 28165.264945699008
# start iteration
# done sorting
# end inner loop
# Iteration 54, inertia 28165.043991936192
# start iteration
# done sorting
# end inner loop
# Iteration 55, inertia 28164.802737973085
# start iteration
# done sorting
# end inner loop
# Iteration 56, inertia 28164.603257576975
# start iteration
# done sorting
# end inner loop
# Iteration 57, inertia 28164.459539219606
# start iteration
# done sorting
# end inner loop
# Iteration 58, inertia 28164.459539219606
# center shift 0.000000e+00 within tolerance 3.062254e-07
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 29278.00493651637
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 28410.979616297293
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 28282.07938632861
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 28249.54588476622
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 28241.038678855854
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 28239.11148836902
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 28238.36515996193
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 28237.946624603774
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 28237.82265701897
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 28237.734855841427
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 28237.734855841427
# center shift 0.000000e+00 within tolerance 3.062254e-07
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 29186.572084803574
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 28558.473526922022
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 28365.364284713807
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 28266.9796833522
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 28211.181803493684
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 28184.83849992336
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 28169.73233572168
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 28163.53424749596
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 28159.205051346587
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 28156.31817916368
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 28155.41941711867
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 28154.867934778413
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 28154.795447746368
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 28154.777338054177
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 28154.777338054177
# center shift 0.000000e+00 within tolerance 3.062254e-07
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 29514.74365971512
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 28805.986901587275
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 28470.65490077915
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 28342.110147519856
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 28273.63143193649
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 28239.486293516
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 28222.435624156333
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 28211.256200243115
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 28201.694675675415
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 28190.300662033398
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 28181.980032617343
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 28176.33750462902
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 28171.363734993076
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 28167.71312407631
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 28165.180911109615
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 28163.74394466257
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 28162.514944435785
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 28161.22371094245
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 28160.16391517216
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 28159.2384854586
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 28158.14371665799
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 28157.40545951356
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 28156.957789670807
# start iteration
# done sorting
# end inner loop
# Iteration 23, inertia 28156.623444763
# start iteration
# done sorting
# end inner loop
# Iteration 24, inertia 28156.476440371116
# start iteration
# done sorting
# end inner loop
# Iteration 25, inertia 28156.42575919942
# start iteration
# done sorting
# end inner loop
# Iteration 26, inertia 28156.31487610233
# start iteration
# done sorting
# end inner loop
# Iteration 27, inertia 28156.277838791368
# start iteration
# done sorting
# end inner loop
# Iteration 28, inertia 28156.11366778954
# start iteration
# done sorting
# end inner loop
# Iteration 29, inertia 28155.92654458378
# start iteration
# done sorting
# end inner loop
# Iteration 30, inertia 28155.654363972055
# start iteration
# done sorting
# end inner loop
# Iteration 31, inertia 28155.48287339071
# start iteration
# done sorting
# end inner loop
# Iteration 32, inertia 28155.326008730688
# start iteration
# done sorting
# end inner loop
# Iteration 33, inertia 28155.21154336311
# start iteration
# done sorting
# end inner loop
# Iteration 34, inertia 28155.21154336311
# center shift 0.000000e+00 within tolerance 3.062254e-07
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 28983.758934505706
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 28265.637370985583
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 28194.125186460402
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 28172.08101751156
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 28162.673570079212
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 28158.418986857865
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 28156.565939590557
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 28154.419712766085
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 28153.368843736447
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 28153.07221458516
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 28153.026736782864
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 28152.995882222087
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 28152.956503770092
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 28152.956503770092
# center shift 0.000000e+00 within tolerance 3.062254e-07

# %%
cluster_labels = kmeans.labels_

# %%
community_json = 'val_communities_10.json'

with open(community_json) as json_file:
    community_labels = json.load(json_file)

# %%
kmeans_labels = dict()
for idx, label in zip(val_spec_labels, cluster_labels):
    kmeans_labels[idx] = label

sorted_kmeans_labels = dict(sorted(kmeans_labels.items()))

sorted_community_labels = dict(sorted(community_labels.items()))

#This should be True
sorted_community_labels.keys() == sorted_kmeans_labels.keys()
# Out:
# True

# %%
community_labels = list(sorted_community_labels.values())
cluster_labels = list(sorted_kmeans_labels.values())

# %%
Counter(community_labels)
# Out:
# Counter({7: 545,
#          6: 244,
#          8: 498,
#          0: 300,
#          10: 201,
#          5: 393,
#          9: 172,
#          1: 28,
#          4: 353,
#          3: 20,
#          2: 9})

# %%
Counter(cluster_labels)
# Out:
# Counter({0: 1006, 2: 573, 1: 909, 3: 275})

# %%
labels = kmeans.labels_
community = list(sorted_community_labels.values())
kmeanclusters = list(sorted_kmeans_labels.values())

mat = confusion_matrix(community, kmeanclusters)
fig, ax = plt.subplots(figsize=(12,4))  

sns.heatmap(mat.T[:4,:], square=False, annot=True, fmt='d', cbar=False, cmap="YlGnBu", ax=ax)
plt.xlabel('igraph communities')
plt.ylabel('kmean cluster');
plt.title('Confusion Matrix for Model A')
plt.savefig('{}_confusion_matrix.png'.format('ModelA'), dpi=300, bbox_inches='tight')

# %%
X_embedded = TSNE(n_components=2).fit_transform(reshaped_latent_vectors)

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.scatterplot(X_embedded[:,0], X_embedded[:,1], hue=cluster_labels, legend='full')
plt.title('TSNE with cluster labels')
plt.savefig('{}_tnse_clusters.png'.format('ModelA_10'), dpi=300, bbox_inches='tight')

# %%
sns.scatterplot(X_embedded[:,0], X_embedded[:,1], hue=community_labels, legend='full')
plt.title('TSNE with Community labels')
plt.savefig('{}_tsne_community.png'.format('ModelA_10'), dpi=300, bbox_inches='tight')

# %%
df = pd.DataFrame()
pca = PCA(n_components=3)
pca_result = pca.fit_transform(X)
df['pca-one'] = pca_result[:,0]
df['pca-two'] = pca_result[:,1] 
df['pca-three'] = pca_result[:,2]
print('Explained variation per principal component: {}'.format(pca.explained_variance_ratio_))
# Out:
# Explained variation per principal component: [0.15787631 0.03440034 0.01957931]

# %%
ax = plt.figure(figsize=(16,10)).gca(projection='3d')
ax.scatter(
    xs=df.loc[:,:]["pca-one"], 
    ys=df.loc[:,:]["pca-two"], 
    zs=df.loc[:,:]["pca-three"], 
    c=cluster_labels, 
    cmap='tab10'
)
ax.set_xlabel('pca-one')
ax.set_ylabel('pca-two')
ax.set_zlabel('pca-three')
plt.title('PCA with Cluster Labels')
plt.savefig('{}_pca_clusters.png'.format("ModelA_10"), dpi=300, bbox_inches='tight')

plt.show()

# %%
ax = plt.figure(figsize=(16,10)).gca(projection='3d')
ax.scatter(
    xs=df.loc[:,:]["pca-one"], 
    ys=df.loc[:,:]["pca-two"], 
    zs=df.loc[:,:]["pca-three"], 
    c=community_labels, 
    cmap='tab10'
)
ax.set_xlabel('pca-one')
ax.set_ylabel('pca-two')
ax.set_zlabel('pca-three')
plt.title('PCA with Community Labels')
plt.savefig('{}_pca_community.png'.format("ModelA_10"), dpi=300, bbox_inches='tight')
plt.show()
